# %% [markdown]
# # QR Problems
#
# Examples of QR problem generation and rendering.

# %%
using GenLAProblems
using Random
Random.seed!(5003)

# %% [markdown]
# ## Generate a QR problem

# %%
A = gen_qr_problem_3()
A

# %% [markdown]
# ## Gram-Schmidt QR display

# %%
W = gram_schmidt_w(A)
h, _ = nM.gram_schmidt_qr(A, W, fig_scale=1.1, tmp_dir="../../tmp")
h

# %% [markdown]
# ## QR tables

# %%
h = nM.qr_tbl_svg(A; fig_scale=1.1, tmp_dir="../../tmp")
h
