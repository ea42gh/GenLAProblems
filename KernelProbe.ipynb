# %% [markdown]
# # Kernel Probe
#
# Run one cell at a time from the top. The goal is to identify the first import or operation that kills the Julia Binder kernel.

# %%
using Random
Random.seed!(42)

# %%
using LinearAlgebra

# %%
using LaTeXStrings

# %%
using LAlatex

# %%
using GenLAProblems

# %%
A_ge, X_ge, B_ge = gen_gj_pb(3, 4, 3; maxint=3, num_rhs=2)
size(A_ge), size(X_ge), size(B_ge)

# %%
display(LAlatex.l_show(L"A = ", A_ge))
